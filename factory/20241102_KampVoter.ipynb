# %% [markdown]
# # KampVoter

# %% [markdown]
# ## Import Library

# %% [markdown]
# ### Basic Libary

# %%
from kamp.preprocess import KampDataLoader
from kamp.models import KampVoter

from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ### Models

# %%
# Forest Models
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# Boosting Models
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier

# Linear Models
from sklearn.linear_model import LogisticRegression

# Discriminan Models
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# Distance Based Models
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# NN Models
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Data Load

# %%
DATA_PATH = './data/경진대회용 주조 공정최적화 데이터셋.csv'


data_loader = KampDataLoader(
    path = DATA_PATH,

    # 처리 안한게 더 좋았음
    # 처리 안한 것 : 0.944
    # 처리 한 것 : 최대 0.922
    do_count_trend=False,
    drop_count=False,

    get_useful_p_data=True,
    p_threshold=0.05,

    outlier_method='iso',
    iso_outlier_rate=0.0075,

    do_resample=False,
    # downsampled_pass_rate=1.0,
    # upsampled_fail_rate_about_pass=0.10,
    # upsample_method='adasyn',

    scale_include_cat=True
)

data_loader.process()

data = data_loader.load()

x_train = data['train_data'].drop('passorfail',axis=1)
y_train = data['train_label']
x_test = data['test_data'].drop('passorfail',axis=1)
y_test=  data['test_label']
# Out:
# ==================== [Data Process Start] ====================
#
# [Process Log] Loading Raw Data...
# [Process Log] Done
#
# [Process Log] Processing Nan Value...
# [Process Log] Done
#
# [Process Log] Encoding Categorical Features...
# [Process Log] Done
#
# [Process Log] Removing Outliers (IsoForest)...
# [Outlier-Remover Log] With Outliers Shape : (89753, 23)
# [Outlier-Remover Log] Without Outliers Shape : (89079, 23)
# [Process Log] Done
#
# [Process Log] T-Testing...
# [Process Log] Done
#
# [Process Log] Data Scaling (MinMaxScaler)...
# [Process Log] Done
#
# [Process Log] Train Test Spliting...
# [Process Log] Done
#
# ======================= [Done] =======================

# %%
x_test
# Out:
#           count  working  facility_operation_cycleTime  production_cycletime  \
# 0      0.576577      1.0                      0.118557              0.278008
# 1      0.291291      1.0                      0.131443              0.253112
# 2      0.243243      1.0                      0.123711              0.246888
# 3      0.819820      1.0                      0.126289              0.275934
# 4      0.759760      1.0                      0.123711              0.244813
# ...         ...      ...                           ...                   ...
# 17811  0.648649      1.0                      0.136598              0.255187
# 17812  0.021021      1.0                      0.144330              0.170124
# 17813  0.336336      1.0                      0.128866              0.251037
# 17814  0.099099      1.0                      0.193299              0.244813
# 17815  0.720721      1.0                      0.131443              0.253112
#
#        low_section_speed  high_section_speed  cast_pressure  \
# 0               0.733333            0.288660       0.927273
# 1               0.733333            0.288660       0.922727
# 2               0.733333            0.288660       0.922727
# 3               0.733333            0.288660       0.918182
# 4               0.733333            0.288660       0.918182
# ...                  ...                 ...            ...
# 17811           0.733333            0.288660       0.918182
# 17812           0.726667            0.288660       0.140909
# 17813           0.700000            0.273196       0.890909
# 17814           0.733333            0.291237       0.927273
# 17815           0.480000            0.262887       0.863636
#
#        biscuit_thickness  upper_mold_temp1  upper_mold_temp2  \
# 0               0.120853          0.091737          0.037099
# 1               0.120853          0.149860          0.039477
# 2               0.132701          0.057423          0.033532
# 3               0.118483          0.123950          0.038526
# 4               0.125592          0.060224          0.037812
# ...                  ...               ...               ...
# 17811           0.113744          0.148459          0.043282
# 17812           0.127962          0.133754          0.026873
# 17813           0.109005          0.127451          0.035196
# 17814           0.118483          0.133053          0.029251
# 17815           0.118483          0.094538          0.030916
#
#        lower_mold_temp1  lower_mold_temp2  sleeve_temperature  \
# 0              0.464183          0.159664            0.051336
# 1              0.544413          0.130952            0.404360
# 2              0.593123          0.086835            0.325598
# 3              0.710602          0.114846            0.271449
# 4              0.673352          0.089636            0.316456
# ...                 ...               ...                 ...
# 17811          0.575931          0.125350            0.263713
# 17812          0.318052          0.097339            0.308720
# 17813          0.550143          0.161765            0.309423
# 17814          0.358166          0.144258            0.094233
# 17815          0.378223          0.063025            0.361463
#
#        EMS_operation_time  tryshot_signal  mold_code  heating_furnace
# 0                    0.00             0.0   0.500000              0.0
# 1                    0.92             0.0   0.333333              0.0
# 2                    0.92             0.0   1.000000              0.0
# 3                    0.92             0.0   1.000000              1.0
# 4                    0.92             0.0   1.000000              0.5
# ...                   ...             ...        ...              ...
# 17811                0.92             0.0   0.166667              1.0
# 17812                0.92             0.0   0.333333              0.5
# 17813                0.92             0.0   0.833333              1.0
# 17814                0.24             0.0   0.000000              0.5
# 17815                0.92             1.0   0.833333              1.0
#
# [17816 rows x 17 columns]

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Best Version

# %% [markdown]
# ```python
# voting_models = {
#     'catboost' : best_catboost,
#     'lgbm' : best_lgbm,
#     'xgb' : best_xgb,
# }
#
# model_weights = [1.5,1,1]
#
# kamp_voter = KampVoter(voting_models=voting_models,
#                        model_weights=model_weights,
#                        voting_method='soft')
# ```
#
# ```python
# "-----------------------------------------------------------"
# f1_score : 0.9614791987673343
#
# confusion matrix :
# [[17142    18]
#  [   32   624]]
#
# classification report :
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     17160
#          1.0       0.97      0.95      0.96       656
#
#     accuracy                           1.00     17816
#    macro avg       0.99      0.98      0.98     17816
# weighted avg       1.00      1.00      1.00     17816
# ```

# %% [markdown]
# ### Base Model Tuning

# %% [markdown]
# #### CatBoostClassifier

# %%
cat_param_grid = {
    'iterations' : [1000, 1500],
    'learning_rate' : [0.01, 0.03, 0.05],
    'depth' : [4, 6],
    'l2_leaf_reg' : [1, 3, 5],
    # 'loss_function' : ['CrossEntropy'],
    'random_seed' : [42],
    'verbose' : [0],
}

random_search = RandomizedSearchCV(
    estimator = CatBoostClassifier(
                           task_type="GPU",
                           devices='0'
                           ),
    param_distributions = cat_param_grid,
    n_iter = 20,
    cv = 3,
    verbose = 2,
    random_state = 42,
    # n_jobs = -1
)

random_search.fit(x_train, y_train)

print(f"Best HyperParameters : {random_search.best_params_}")

best_catboost = random_search.best_estimator_
# Best HyperParameters : {'verbose': 0, 'random_seed': 42, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 1500, 'depth': 6}
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.4min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.8min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=3, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time=  58.6s
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.4min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.4min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=5, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time=  56.8s
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.01, random_seed=42, verbose=0; total time=  59.2s
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time=  57.8s
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.03, random_seed=42, verbose=0; total time=  59.9s
# [CV] END depth=6, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=6, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=5, learning_rate=0.01, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=6, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.1min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.6min
# [CV] END depth=4, iterations=1500, l2_leaf_reg=1, learning_rate=0.05, random_seed=42, verbose=0; total time= 1.5min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time=  55.9s
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time= 1.0min
# [CV] END depth=4, iterations=1000, l2_leaf_reg=1, learning_rate=0.03, random_seed=42, verbose=0; total time=  58.2s
# Best HyperParameters : {'verbose': 0, 'random_seed': 42, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 1500, 'depth': 6}

# %% [markdown]
# #### LGBMClassifier

# %%
# 2m 20s
lgbm_param_grid = {
    # 'objective' : ['binary'],
    'boosting_type' : ['gbdt', 'dart'],
    # 'n_estimators' : [100, 150, 200, 250],
    'learning_rate' : [0.01, 0.1, 0.5],
    'max_depth' : [-1],
    'random_state' : [42],
    'verbose' : [0]
}

random_search = RandomizedSearchCV(
    estimator = LGBMClassifier(),
    param_distributions = lgbm_param_grid,
    n_iter = 30,
    cv = 3,
    verbose = 2,
    random_state = 42,
    n_jobs = -1
)

random_search.fit(x_train, y_train)

print(f"Best HyperParameters : {random_search.best_params_}")

best_lgbm = random_search.best_estimator_
# {'verbose': 0, 'random_state': 42, 'max_depth': -1, 'learning_rate': 0.1, 'boosting_type': 'gbdt'}
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# /home/greatsangho/miniconda3/envs/ml/lib/python3.9/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 6 is smaller than n_iter=30. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [CV] END boosting_type=gbdt, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time=16.3min
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [CV] END boosting_type=gbdt, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time=20.8min
# [CV] END boosting_type=dart, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=21.5min
# [CV] END boosting_type=dart, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=21.7min
# [CV] END boosting_type=dart, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=21.7min
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END boosting_type=gbdt, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=21.9min
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV] END boosting_type=gbdt, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time=22.0min
# [CV] END boosting_type=gbdt, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=22.2min
# [CV] END boosting_type=gbdt, learning_rate=0.01, max_depth=-1, random_state=42, verbose=0; total time=22.2min
# [CV] END boosting_type=gbdt, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.3min
# [CV] END boosting_type=gbdt, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.4min
# [CV] END boosting_type=dart, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.5min
# [CV] END boosting_type=dart, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time=22.5min
# [CV] END boosting_type=gbdt, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.5min
# [CV] END boosting_type=dart, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.5min
# [CV] END boosting_type=dart, learning_rate=0.1, max_depth=-1, random_state=42, verbose=0; total time=22.5min
# [CV] END boosting_type=dart, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time= 1.7min
# [CV] END boosting_type=dart, learning_rate=0.5, max_depth=-1, random_state=42, verbose=0; total time= 6.2min
# Best HyperParameters : {'verbose': 0, 'random_state': 42, 'max_depth': -1, 'learning_rate': 0.1, 'boosting_type': 'gbdt'}

# %% [markdown]
# #### XGBClassifier

# %%
xgb_param_grid = {
    # 'booster' : ['gbtree'],
    'n_estimators' : [100, 150, 200],
    'learning_rate' : [0.1, 0.3, 0.5],
    'max_depth' : [10, 12, 14, 16],
    'random_state' : [42],
    'verbosity' : [0]
}

random_search = RandomizedSearchCV(
    estimator = XGBClassifier(tree_method="hist", device="cuda"),
    param_distributions = xgb_param_grid,
    n_iter = 30,
    cv = 3,
    verbose = 2,
    random_state = 42,
    # n_jobs = -1
)

random_search.fit(x_train, y_train)

print(f"Best HyperParameters : {random_search.best_params_}")

best_xgb = random_search.best_estimator_
# {'verbosity': 0, 'random_state': 42, 'n_estimators': 150, 'max_depth': 16, 'learning_rate': 0.5}
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.8s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.6s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   4.9s
# [CV] END learning_rate=0.1, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   2.2s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=150, random_state=42, verbosity=0; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.9s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.1s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=150, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=200, random_state=42, verbosity=0; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=200, random_state=42, verbosity=0; total time=   1.8s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=16, n_estimators=100, random_state=42, verbosity=0; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=14, n_estimators=200, random_state=42, verbosity=0; total time=   1.2s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   4.5s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.6s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=200, random_state=42, verbosity=0; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=12, n_estimators=100, random_state=42, verbosity=0; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.7s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.3s
# [CV] END learning_rate=0.3, max_depth=16, n_estimators=150, random_state=42, verbosity=0; total time=   1.4s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# [CV] END learning_rate=0.3, max_depth=14, n_estimators=100, random_state=42, verbosity=0; total time=   1.0s
# Best HyperParameters : {'verbosity': 0, 'random_state': 42, 'n_estimators': 150, 'max_depth': 16, 'learning_rate': 0.5}

# %% [markdown]
# ### Voting Model Tuning

# %%
voting_models = {
    'catboost' : best_catboost,
    'lgbm' : best_lgbm,
    'xgb' : best_xgb,
    # 'rf' : RandomForestClassifier(random_state=42)
}

model_weights = [1.5,
                 1.0,
                 1.0,
                #  1.0
                 ]

kamp_voter = KampVoter(voting_models = voting_models,
                       model_weights = model_weights, 
                       voting_method = 'soft')

# %%
kamp_voter.fit(x_train, y_train)
# Out:
# [Voting] ................. (1 of 3) Processing catboost, total=  16.2s
# [Voting] ..................... (2 of 3) Processing lgbm, total=   0.3s
# [Voting] ...................... (3 of 3) Processing xgb, total=   0.9s
# VotingClassifier(estimators=[('catboost',
#                               <catboost.core.CatBoostClassifier object at 0x7fc4fc906c70>),
#                              ('lgbm',
#                               LGBMClassifier(random_state=42, verbose=0)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             device='cuda',
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             ev...
#                                             interaction_constraints=None,
#                                             learning_rate=0.5, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=16,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=150, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=42, ...))],
#                  verbose=1, voting='soft', weights=[1.5, 1.0, 1.0])

# %% [markdown]
# ## Evaluation

# %%
kamp_voter.evaluate(x_train, y_train)
# Out:
# f1_score : 0.9992369324685234
#
# confusion matrix :
# [[68640     0]
#  [    4  2619]]
#
# classification report :
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     68640
#          1.0       1.00      1.00      1.00      2623
#
#     accuracy                           1.00     71263
#    macro avg       1.00      1.00      1.00     71263
# weighted avg       1.00      1.00      1.00     71263

# %%
kamp_voter.evaluate(x_test, y_test)
# Out:
# f1_score : 0.9606177606177606
#
# confusion matrix :
# [[17143    17]
#  [   34   622]]
#
# classification report :
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     17160
#          1.0       0.97      0.95      0.96       656
#
#     accuracy                           1.00     17816
#    macro avg       0.99      0.97      0.98     17816
# weighted avg       1.00      1.00      1.00     17816

# %%
# CatBoost
# [[17138    22]
#  [   35   621]]

# LGBM
# [[17139    21]
#  [   34   622]]

# XGB
# [[17140    20]
#  [   34   622]]
